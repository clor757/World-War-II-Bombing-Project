# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csvfile = "C:/Users/bryan_j7mwyoj/Desktop/Project 2/operations.csv"
WWII_ops = pd.read_csv(csvfile, low_memory = False)
WWII_ops.head()
# Out:
#    Mission ID Mission Date Theater of Operations Country Air Force  \
# 0           1    8/15/1943                   MTO     USA     12 AF
# 1           2    8/15/1943                   PTO     USA      5 AF
# 2           3    8/15/1943                   MTO     USA     12 AF
# 3           4    8/15/1943                   MTO     USA     12 AF
# 4           5    8/15/1943                   PTO     USA      5 AF
#
#          Unit ID Aircraft Series Callsign Mission Type          Takeoff Base  \
# 0  27 FBG/86 FBG             A36      NaN          NaN  PONTE OLIVO AIRFIELD
# 1         400 BS             B24      NaN            1                   NaN
# 2  27 FBG/86 FBG             A36      NaN          NaN  PONTE OLIVO AIRFIELD
# 3  27 FBG/86 FBG             A36      NaN          NaN  PONTE OLIVO AIRFIELD
# 4         321 BS             B24      NaN            1                   NaN
#
#    ... Incendiary Devices Weight (Tons) Fragmentation Devices  \
# ...

# %%
WWII_ops.drop(['Callsign', 'Source ID', 'Target Type', 'Target Industry', 'Target Priority', 'Bomb Damage Assessment', 'Air Force',
              'Unit ID', 'Mission Type', 'Target ID', 'Aircraft Returned', 'Aircraft Failed', 'Aircraft Damaged', 'Aircraft Lost', 'Airborne Aircraft',
              'Attacking Aircraft', 'Bombing Aircraft', 'Time Over Target'], axis = 1, inplace = True)
WWII_ops.rename(columns = {'Altitude (Hundreds of Feet)': 'Altitude', 'High Explosives Weight (Pounds)': "High Explosives Weight LBS",
                          'High Explosives Weight (Tons)': 'High Explosives Weight Tons', 'Incendiary Devices Weight (Pounds)': 'Incendiary Devices Weight LBS',
                          'Incendiary Devices Weight (Tons)': 'Incendiary Devices Weight Tons', 'Fragmentation Devices Weight (Pounds)': 'Fragmentation Devices Weight LBS',
                          'Fragmentation Devices Weight (Tons)': 'Fragmentation Devices Weight Tons',
                          'Total Weight (Pounds)': 'Total Weight LBS', 'Total Weight (Tons)': 'Total Weight Tons'}, inplace = True)

# %%
WWII_ops
# Out:
#         Mission ID Mission Date Theater of Operations        Country  \
# 0                1    8/15/1943                   MTO            USA
# 1                2    8/15/1943                   PTO            USA
# 2                3    8/15/1943                   MTO            USA
# 3                4    8/15/1943                   MTO            USA
# 4                5    8/15/1943                   PTO            USA
# 5                6    8/15/1943                   PTO            USA
# 6                7    8/15/1943                   PTO            USA
# 7                8    8/15/1943                   PTO            USA
# 8                9    8/15/1943                   MTO            USA
# 9               10    8/15/1943                   MTO            USA
# 10              11    8/15/1943                   CBI            USA
# 11              12    8/15/1943                   ETO  GREAT BRITAIN
# 12              13    8/15/1943                   ETO  GREAT BRITAIN
# ...

# %%
rds_connection_string = "postgres:postgres@localhost:5432/WWII_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['wwii_ops', 'WWII_ops']

# %%
WWII_ops.to_sql(name = 'WWII_ops', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-c0d698bf05a7> in <module>
# ----> 1 WWII_ops.to_sql(name = 'WWII_ops', con=engine, if_exists='append', index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     458     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [mission_id, mission_date, theater_of_operations, country, aircraft, takeoff_base, takeoff_location, takeoff_latitude, takeoff_longitude, target_country, target_city, target_latitude, target_longitude, altitude, high_explosives, high_explosives_type, high_explosives_weight_lbs, high_explosives_weight_tons, incendiary_devices, incendiary_devices_type, incendiary_devices_weight_lbs, incendairy_devices_weight_tons, fragmentation_devices, fragmentation_devices_type, fragmentation_devices_weight_lbs, fragmentation_devices_weight_tons, total_weight_lbs, total_weight_tons]
# Index: []
#
# [0 rows x 28 columns]
